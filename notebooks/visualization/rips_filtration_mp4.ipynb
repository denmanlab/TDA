# %% [markdown]
# # Vietoris-Rips Filtration Visualization (mp4)
#
# author @emilyekstrum
# 4/8/26

# %%
import importlib
import utils

utils = importlib.reload(utils)
export_filtration_mp4 = utils.export_filtration_mp4
list_repo_embeddings = utils.list_repo_embeddings

# %% [markdown]
# ### Set repository data source to select embedding

# %%
# embedding selection
available_embeddings = list_repo_embeddings()
for filename, info in available_embeddings.items():
    print(f"{filename}: {info['session_names']}")
# Out:
# Loading model: Using CPU
# loaded model
# Loading model: Using CPU
# CUDA compatibility issue detected, forcing CPU mapping
# loaded using CPU unpickler
# moving d4 model from cuda:0 to cpu
# Loading model: Using CPU
# CUDA compatibility issue detected, forcing CPU mapping
# loaded using CPU unpickler
# moving d4 model from cuda:0 to cpu
# Loading model: Using CPU
# CUDA compatibility issue detected, forcing CPU mapping
# loaded using CPU unpickler
# moving d4 model from cuda:0 to cpu
# Loading model: Using CPU
# loaded model
# LGN_3d_CEBRA_unsup_time_color_exchange_shuffled.pkl: ['d4', 'd5', 'd6', 'C153', 'C155', 'C159', 'C160', 'C161']
# LGN_8d_CEBRA_unsup_time_color_exchange.pkl: ['d4', 'd5', 'd6', 'C153', 'C155', 'C159', 'C160', 'C161']
# V1_3d_CEBRA_unsup_time_color_exchange.pkl: ['d4', 'd5', 'd6', 'C153', 'C155', 'C159', 'C160', 'C161']
# V1_8d_CEBRA_unsup_time_color_exchange.pkl: ['d4', 'd5', 'd6', 'C153', 'C155', 'C159', 'C160', 'C161']
# ...

# %% [markdown]
# ### Select embedding and set video display settings

# %%
embedding_filename = "V1_8d_CEBRA_unsup_time_luminance_flash.pkl"
session_name = "C161"
output_name = "V1_8d_CEBRA_unsup_time_luminance_flash_C161_filtration.mp4"

n_samples = 400 # number of points to down sample embedding - raw embeddings are ~5,000 points
sampling_method = "random"
random_seed = 42
diameter_range = (0.0, 0.5)
n_frames = 48
fps = 8
show_spheres = True

# %% [markdown]
# ### Create video

# %%
video = export_filtration_mp4(
    embedding_filename=embedding_filename,
    session_name=session_name,
    output_name=output_name,
    n_samples=n_samples,
    sampling_method=sampling_method,
    random_seed=random_seed,
    diameter_range=diameter_range,
    n_frames=n_frames,
    fps=fps,
    show_spheres=show_spheres)
# Out:
# Loading model: Using CPU
# loaded model
# Frame 1/48
# Frame 2/48
# Frame 3/48
# Frame 4/48
# Frame 5/48
# Frame 6/48
# Frame 7/48
# Frame 8/48
# Frame 9/48
# Frame 10/48
# Frame 11/48
# Frame 12/48
# Frame 13/48
# Frame 14/48
# Frame 15/48
# Frame 16/48
# Frame 17/48
# Frame 18/48
# Frame 19/48
# Frame 20/48
# Frame 21/48
# Frame 22/48
# Frame 23/48
# Frame 24/48
# Frame 25/48
# Frame 26/48
# Frame 27/48
# Frame 28/48
# Frame 29/48
# Frame 30/48
# Frame 31/48
# Frame 32/48
# Frame 33/48
# Frame 34/48
# Frame 35/48
# Frame 36/48
# Frame 37/48
# Frame 38/48
# Frame 39/48
# Frame 40/48
# Frame 41/48
# Frame 42/48
# Frame 43/48
# Frame 44/48
# Frame 45/48
# Frame 46/48
# Frame 47/48
# Frame 48/48
# original embedding shape: (5000, 8)
# downsampled embedding shape: (400, 8)
# selected embedding: C161
# embedding source: /Users/emilyekstrum/repos/TDA/data/CEBRA_embedding_examples/V1_8d_CEBRA_unsup_time_luminance_flash.pkl
# ...
